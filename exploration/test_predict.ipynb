# %%
import torch
import torch.nn as nn
from models.cycle_gan_model import CycleGANModel
from options.test_options import TestOptions
import cv2
from PIL import Image
import numpy as np
from data import create_dataset
from torchvision import transforms
import matplotlib.pyplot as plt

# %%
opt = model.opt

opt.dataroot = '/code/dl/pytorch-CycleGAN-and-pix2pix/datasets/makeup2/'

dataset = [data for data in create_dataset(opt)]
# Out:
# dataset [UnalignedDataset] was created

# %%
model = torch.load('../model.pkl')

# %%
image = '../datasets/makeup2/testA/03480298a56454e8fab7df9efbff8040.png'

# %%
im = cv2.imread(image)

# %%
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
im.shape
# Out:
# (361, 361, 3)

# %%
img = Image.fromarray(im)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=361x361 at 0x7F4C24BF8400>

# %%
im = cv2.resize(im, (128, 128), interpolation = cv2.INTER_AREA)

# %%
im.shape
# Out:
# (128, 128, 3)

# %%
im_1 = (im/128)-1

# %%
data=torch.tensor(data=[im_1.swapaxes(0,1).swapaxes(0,2)], dtype=torch.double)

# %%
pred = model.netG_A(dataset[3]['A'])

# %%
array = pred.detach().numpy()

# %%
array = array[0].swapaxes(0,2).swapaxes(0,1)
array= ((array+1)*127.99).astype('uint8')

# %%
img = Image.fromarray(im, 'RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F4C21A1C710>

# %%
img = Image.fromarray(array, 'RGB')
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F4C24D5F438>
