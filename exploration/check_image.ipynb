# %%
import os

# %%
image_folder = '/resource/data/makeup/images/'

# %%
makeup_files = [file for file in os.listdir(image_folder + 'makeup') if '.png' in file]

# %%
len(makeup_files)
# Out:
# 2719

# %%
non_makeup_files = [file for file in os.listdir(image_folder + 'non-makeup') if '.png' in file]

# %%
len(non_makeup_files)
# Out:
# 1115
